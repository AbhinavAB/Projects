# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/Data_Collection_for_Image_Classification_Bing_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bing_image_downloader import downloader
#downloader.download("elephant in africa", limit=5,  output_dir='images', adult_filter_off=True, force_replace=False)
downloader.download("elephant in africa", limit=5,  output_dir='../../DataSets/images', adult_filter_off=True, force_replace=False)
# Out:
# [%] Downloading Images to /Users/abhinavmohanty/Documents/Python/DE/../../DataSets/images/elephant in africa
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://mattibfotography.com/wp-content/uploads/2019/09/52-year-old-female-Tusker-Elephant-in-the-drought-Kenya-Africa.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://4.bp.blogspot.com/-PaI5J7P95JM/UOEqxpMfLSI/AAAAAAAAAU0/mqkoV1EUT5s/s1600/African+Elephant.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/0d/5a/64/0d5a64869d5c588c3a133fd14aff22c3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://4.bp.blogspot.com/-gTS9PgWYVxE/UOEq15mWxEI/AAAAAAAAAVI/cM67V7VTYj4/s1600/African+Wild+Elephant.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.thebooktrail.com/wp-content/uploads/2018/08/1-16.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 5 images.
# ...
#
# ...

# %%
#downloader.download("kangaroo in australia", limit=5,  output_dir='images', adult_filter_off=True, force_replace=False)
downloader.download("kangaroo in australia", limit=5,  output_dir='../../DataSets/images', adult_filter_off=True, force_replace=False)
# Out:
# [%] Downloading Images to /Users/abhinavmohanty/Documents/Python/DE/../../DataSets/images/kangaroo in australia
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.theanimalfacts.com/wp-content/uploads/2021/01/Kangaroo-Joey-ARP-2-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://animalia-life.com/data_images/kangaroo/kangaroo1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://images.thestar.com/b2BBT9BcN9QXYsCvVtiiiqN3Fv8=/1199x803/smart/filters:cb(2700061000)/https://www.thestar.com/content/dam/thestar/life/travel/2012/06/06/travel_deals_hop_on_down_to_australia_for_a_great_holiday_on_kangaroo_island/kangaroo_inaustralia.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.thepoortraveler.net/wp-content/uploads/2015/08/Kangaroo.jpg
# [%] File Downloaded !
#
# ...

# %%
#!ls images/ -alrt
# !ls ../DataSets/images/ -alrt
# Out:
# ls: -alrt: No such file or directory
# ../DataSets/images/:
# elephant in africa    kangaroo in australia

# %%
#!ls 'images'/'elephant in africa'
# !ls '../DataSets/images'/'elephant in africa'
# Out:
# Image_1.jpg Image_2.jpg Image_3.jpg Image_4.jpg Image_5.jpg

# %%
#!ls 'images'/'kangaroo in australia'
# !ls '../DataSets/images'/'kangaroo in australia'
# Out:
# Image_1.jpg  Image_2.jpg  Image_3.jpeg Image_4.jpg  Image_5.png

# %%
from IPython.display import Image
#Image("images/elephant in africa/Image_5.jpg")
Image("../../DataSets/images/elephant in africa/Image_5.jpg")

# %%
#Image("images/kangaroo in australia/Image_3.jpg")
Image("../DataSets/images/kangaroo in australia/Image_4.jpg")

# %%
from six import BytesIO
from PIL import Image
import numpy as np
import glob
import os

import matplotlib
import matplotlib.pyplot as plt

# %%
def load_image_into_numpy_array(path):
  img_data = open(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape((im_height, im_width, 3)).astype(np.uint8)

# %%
#elephant_image_path = "/content/images/elephant in africa/*"
elephant_image_path = "../../DataSets/images/elephant in africa/*"
elephant_images_np = []
for iname in glob.glob(elephant_image_path):
  elephant_images_np.append(load_image_into_numpy_array(iname))

# %%
plt.rcParams['figure.figsize'] = [14, 7]

for idx, elephant_image_np in enumerate(elephant_images_np):
  plt.subplot(2, 3, idx+1)
  plt.imshow(elephant_image_np)
plt.show()
