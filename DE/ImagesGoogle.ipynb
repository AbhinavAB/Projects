# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/Data_Collection_for_Image_Classification_Google_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()

# %% [markdown]
# https://google-images-download.readthedocs.io/en/latest/arguments.html

# %%
arguments = {"keywords":"polar bear in artic,penguin in antartica","limit":6,"format":"jpg","print_urls":True, "output_directory":"../DataSets/downloads"}
paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = polar bear in artic
# Evaluating...
# Starting Download...
# Image URL: https://c402277.ssl.cf1.rackcdn.com/photos/18695/images/hero_small/Polar_bear_on_ice_in_Svalbard_Norway_WW294883.jpg?1582733867
# Completed Image ====> 1.polar_bear_on_ice_in_svalbard_norway_ww294883.jpg
# Image URL: https://cdn.britannica.com/52/162652-050-6A676116/Polar-bears-ice-floe-Norway.jpg
# Completed Image ====> 2.polar-bears-ice-floe-norway.jpg
# Image URL: https://www.intrepidtravel.com/adventures/wp-content/uploads/2019/01/Peregrine-Adventures-Norway_Svalbard_June-06-2018-49.jpg
# Completed Image ====> 3.peregrine-adventures-norway_svalbard_june-06-2018-49.jpg
# Image URL: https://cdn.cnn.com/cnnnext/dam/assets/200720030735-01-polar-bear-svalbard-0709-super-tease.jpg
# Completed Image ====> 4.200720030735-01-polar-bear-svalbard-0709-super-tease.jpg
# ...

# %%
#!ls downloads/
# !ls ../DataSets/downloads/
# Out:
# penguin in antartica polar bear in artic

# %%
#!ls downloads/'polar bear in artic'
# !ls ../DataSets/downloads/'polar bear in artic'
# Out:
# 1.polar_bear_on_ice_in_svalbard_norway_ww294883.jpg
# 2.polar-bears-ice-floe-norway.jpg
# 3.peregrine-adventures-norway_svalbard_june-06-2018-49.jpg
# 4.200720030735-01-polar-bear-svalbard-0709-super-tease.jpg
# 5.polar-bear-yer.jpg
# 6.polar-bear-climbing-on-ice-%c2%a9-richard-barrett-_-wwf-uk-scaled-e1583271103647.jpg

# %%
#!ls downloads/'penguin in antartica'
# !ls ../DataSets/downloads/'penguin in antartica'
# Out:
# 1.b190563d4eab20ff91605a223f2cf6724e8b4603.jpeg
# 2.antarctica-penguins.jpg
# 3.adelie-penguins_dominic-barrington.jpg
# 4.medium_ww267491.jpg
# 5.img_6074_anke-timmerberg.jpg
# 6.polar_antarctica_emperor_penguins_weddell_sea_thumbnail.jpg

# %%
from six import BytesIO
from PIL import Image
import numpy as np
import glob
import os

import matplotlib
import matplotlib.pyplot as plt

# %%
def load_image_into_numpy_array(path):
  img_data = open(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape((im_height, im_width, 3)).astype(np.uint8)

# %%
#polar_image_path = "/content/downloads/polar bear in artic/*"
polar_image_path = "../DataSets/downloads/polar bear in artic/*"
polar_images_np = []
for iname in glob.glob(polar_image_path):
  polar_images_np.append(load_image_into_numpy_array(iname))

# %%
plt.rcParams['figure.figsize'] = [14, 7]

for idx, polar_image_np in enumerate(polar_images_np):
  plt.subplot(2, 3, idx+1)
  plt.imshow(polar_image_np)
plt.show()

# %%
#penguin_image_path = "/content/downloads/penguin in antartica/*"
penguin_image_path = "../DataSets/downloads/penguin in antartica/*"
penguin_images_np = []
for iname in glob.glob(penguin_image_path):
  penguin_images_np.append(load_image_into_numpy_array(iname))

# %%
plt.rcParams['figure.figsize'] = [14, 7]

for idx, penguin_image_np in enumerate(penguin_images_np):
  plt.subplot(2, 3, idx+1)
  plt.imshow(penguin_image_np)
plt.show()
